# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/sk

# %%
# %%sql
# DROP TABLE IF EXISTS CustomerData;
# CREATE TABLE CustomerData (
#     id INT PRIMARY KEY,
#     customer_name VARCHAR(50),
#     email VARCHAR(100),
#     phone_number VARCHAR(15),
#     location VARCHAR(100),
#     amount DECIMAL(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO CustomerData VALUES
# (1, 'Ravi', 'ravi@example.com', '9876543210', 'Chennai', 5000.00),
# (2, 'Priya', 'priya12@example.com', '9876543211', 'Bangalore', 1800.00),
# (3, 'Arjun', 'arjun@example.com', NULL, 'Hyderabad', 1500.00),
# (4, 'Meena', NULL, NULL, 'Mumbai', 2500.00),
# (5, 'Karthik', 'karthik@example.com', '9876543212', NULL, 3000.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# []

# %%
# %%sql
# UPDATE CustomerData
# SET amount = NULL
# WHERE customer_name = 'Priya';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM CustomerData;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(1, 'Ravi', 'ravi@example.com', '9876543210', 'Chennai', Decimal('5000.00')),
#  (2, 'Priya', 'priya12@example.com', '9876543211', 'Bangalore', None),
#  (3, 'Arjun', 'arjun@example.com', None, 'Hyderabad', Decimal('1500.00')),
#  (4, 'Meena', None, None, 'Mumbai', Decimal('2500.00')),
#  (5, 'Karthik', 'karthik@example.com', '9876543212', None, Decimal('3000.00'))]

# %%
# %%sql
# SELECT
#     customer_name,
#     amount,
#     CASE
#         WHEN amount IS NULL THEN 'No Spend'
#         WHEN amount > 4000 THEN 'High Spender'
#         WHEN amount BETWEEN 2000 AND 4000 THEN 'Medium Spender'
#         WHEN amount < 2000 THEN 'Low Spender'
#     END AS spenders
# FROM CustomerData;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [('Ravi', Decimal('5000.00'), 'High Spender'),
#  ('Priya', None, 'No Spend'),
#  ('Arjun', Decimal('1500.00'), 'Low Spender'),
#  ('Meena', Decimal('2500.00'), 'Medium Spender'),
#  ('Karthik', Decimal('3000.00'), 'Medium Spender')]

# %%
# %%sql
# SELECT *
# FROM CustomerData
# WHERE email IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(4, 'Meena', None, None, 'Mumbai', Decimal('2500.00'))]

# %%
# %%sql
# SELECT *
# FROM CustomerData
# WHERE phone_number IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [(3, 'Arjun', 'arjun@example.com', None, 'Hyderabad', Decimal('1500.00')),
#  (4, 'Meena', None, None, 'Mumbai', Decimal('2500.00'))]

# %%
# %%sql
# SELECT *
# FROM CustomerData
# WHERE phone_number IS NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(1, 'Ravi', 'ravi@example.com', '9876543210', 'Chennai', Decimal('5000.00')),
#  (2, 'Priya', 'priya12@example.com', '9876543211', 'Bangalore', None),
#  (5, 'Karthik', 'karthik@example.com', '9876543212', None, Decimal('3000.00'))]

# %%
# %%sql
# SELECT
#     customer_name,
#     IFNULL(amount,0) AS amount
# FROM CustomerData;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [('Ravi', Decimal('5000.00')),
#  ('Priya', Decimal('0.00')),
#  ('Arjun', Decimal('1500.00')),
#  ('Meena', Decimal('2500.00')),
#  ('Karthik', Decimal('3000.00'))]

# %%
# %%sql
# SELECT COUNT(*) AS total_null_emails
# FROM CustomerData
# WHERE email IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(1,)]

# %%
# %%sql
# SELECT COUNT(amount) AS non_null_amounts
# FROM CustomerData;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(4,)]

# %%
# %%sql
# SELECT SUM(amount) AS total_sales
# FROM CustomerData;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(Decimal('12000.00'),)]
